# %%
#import library
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import quandl
from pathlib import Path

# %% [markdown]
# ### Whale Portfolio

# %%
#create path
whale_csv = pd.read_csv("Resources/whale_return.csv")

whale_data = pd.read_csv("Resources/whale_return.csv")
whale_data.head()
# Out:
#        Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  3/2/2015                        NaN                 NaN
# 1  3/3/2015                  -0.001266           -0.004981
# 2  3/4/2015                   0.002230            0.003241
# 3  3/5/2015                   0.004016            0.004076
# 4  3/6/2015                  -0.007905           -0.003574
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098

# %%
whale_data.set_index(pd.to_datetime(whale_data['Date'], infer_datetime_format=True), inplace=True)
whale_data
# Out:
#                  Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02   3/2/2015                        NaN                 NaN
# 2015-03-03   3/3/2015                  -0.001266           -0.004981
# 2015-03-04   3/4/2015                   0.002230            0.003241
# 2015-03-05   3/5/2015                   0.004016            0.004076
# 2015-03-06   3/6/2015                  -0.007905           -0.003574
# ...               ...                        ...                 ...
# 2019-04-25  4/25/2019                  -0.000285           -0.001291
# 2019-04-26  4/26/2019                   0.008149            0.009162
# 2019-04-29  4/29/2019                   0.001254            0.002719
# 2019-04-30  4/30/2019                  -0.001295           -0.002211
# 2019-05-01   5/1/2019                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1060 rows x 5 columns]

# %%
whale_data.drop(columns = ['Date'], inplace = True)
whale_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
#count nulls
whale_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
#drop nulls
whale_data = whale_data.dropna()

# %%
#check if nulls are gone
whale_data
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1059 rows x 4 columns]

# %% [markdown]
# ### Algo Portfolio

# %%
algo_csv = pd.read_csv("Resources/algo_returns.csv")
algo_data= pd.read_csv("Resources/algo_returns.csv")
algo_data
# Out:
#            Date    Algo 1    Algo 2
# 0     5/28/2014  0.001745       NaN
# 1     5/29/2014  0.003978       NaN
# 2     5/30/2014  0.004464       NaN
# 3      6/2/2014  0.005692       NaN
# 4      6/3/2014  0.005292       NaN
# ...         ...       ...       ...
# 1236  4/25/2019  0.000682 -0.007247
# 1237  4/26/2019  0.002981  0.005256
# 1238  4/29/2019  0.005208  0.002829
# 1239  4/30/2019 -0.002944 -0.001570
# 1240   5/1/2019  0.000094 -0.007358
#
# [1241 rows x 3 columns]

# %%
algo_data.set_index(pd.to_datetime(algo_data['Date'], infer_datetime_format=True), inplace=True)
algo_data.head()
# Out:
#                  Date    Algo 1  Algo 2
# Date
# 2014-05-28  5/28/2014  0.001745     NaN
# 2014-05-29  5/29/2014  0.003978     NaN
# 2014-05-30  5/30/2014  0.004464     NaN
# 2014-06-02   6/2/2014  0.005692     NaN
# 2014-06-03   6/3/2014  0.005292     NaN

# %%
algo_data.drop(columns = ['Date'], inplace = True)
algo_data.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
#count null data
algo_data.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
#drop nul data
algo_data = algo_data.dropna()

# %%
algo_data.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ### SP500 History

# %%
sp500_csv = pd.read_csv("Resources/sp500_history.csv")
sp500_data = pd.read_csv("Resources/sp500_history.csv")
sp500_data.head()
# Out:
#         Date       Close
# 0  23-Apr-19  $2,933.68
# 1  22-Apr-19  $2,907.97
# 2  18-Apr-19  $2,905.03
# 3  17-Apr-19  $2,900.45
# 4  16-Apr-19  $2,907.06

# %%
#check data type
sp500_data.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
#fix data type
sp500_data["Close"] = sp500_data["Close"].str.replace("$", "")
sp500_data["Close"] = sp500_data["Close"].str.replace(",", "")
# Out:
# <ipython-input-16-aa8dc833f439>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   sp500_data["Close"] = sp500_data["Close"].str.replace("$", "")

# %%
sp500_data.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
sp500_data["Close"] = sp500_data["Close"].astype('float')
print(sp500_data.dtypes)
sp500_data.head()
# Out:
# Date      object
# Close    float64
# dtype: object
#         Date    Close
# 0  23-Apr-19  2933.68
# 1  22-Apr-19  2907.97
# 2  18-Apr-19  2905.03
# 3  17-Apr-19  2900.45
# 4  16-Apr-19  2907.06

# %%
#set the index
sp500_data.set_index(pd.to_datetime(sp500_data['Date'], infer_datetime_format=True), inplace=True)
sp500_data.head()
# Out:
#                  Date    Close
# Date
# 2019-04-23  23-Apr-19  2933.68
# 2019-04-22  22-Apr-19  2907.97
# 2019-04-18  18-Apr-19  2905.03
# 2019-04-17  17-Apr-19  2900.45
# 2019-04-16  16-Apr-19  2907.06

# %%
#drop the date column
sp500_data.drop(columns = ['Date'], inplace = True)
sp500_data.head()
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
#calculate the daily returns
sp500_data = sp500_data.pct_change()
sp500_data.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
#drop the nulls 
sp500_data = sp500_data.dropna()
sp500_data
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
#change the 'Close' column
columns = ['SP500 Close']
sp500_data.columns = columns
sp500_data.head()
# Out:
#             SP500 Close
# Date
# 2019-04-22    -0.008764
# 2019-04-18    -0.001011
# 2019-04-17    -0.001577
# 2019-04-16     0.002279
# 2019-04-15    -0.000509

# %% [markdown]
# ### Combine all portfolios

# %%
all_portfolios = pd.concat([whale_data, algo_data, sp500_data], axis = 'columns', join = 'inner')
all_portfolios
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# ...                                 ...                     ...       ...
# 2019-04-15                     0.000398               -0.010492 -0.004331
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
#
#               Algo 2  SP500 Close
# Date
# 2015-03-03 -0.000949     0.004408
# 2015-03-04  0.002416    -0.001195
# 2015-03-05  0.004323     0.014378
# 2015-03-06 -0.011460    -0.003929
# 2015-03-09  0.001303     0.017254
# ...              ...          ...
# 2019-04-15 -0.004572    -0.000509
# 2019-04-16  0.002899     0.002279
# 2019-04-17 -0.005228    -0.001577
# 2019-04-18 -0.001229    -0.001011
# 2019-04-22 -0.001936    -0.008764
#
# [1042 rows x 7 columns]

# %% [markdown]
# ### Performance Analysis

# %%
#plot daily performance on all portfolios
whale_data.plot(figsize = (20, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
algo_data.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sp500_data.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#cumulative returns
cumulative_returns_whale = (1 + whale_data).cumprod()

cumulative_returns_whale.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
cumulative_returns_algo = (1 + algo_data).cumprod()

# %%
cumulative_returns_algo.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
cumulative_returns_sp500 = (1 + sp500_data).cumprod()
cumulative_returns_sp500.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Risk Analysis

# %%
cumulative_returns_all = (1 + all_portfolios).cumprod()
cumulative_returns_all.plot(figsize = (15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#visualize the box plot for each portfolio 
whale_data.plot.box()
# Out:
# <AxesSubplot:>

# %%
algo_data.plot.box()
# Out:
# <AxesSubplot:>

# %%
sp500_data.plot.box()
# Out:
# <AxesSubplot:>

# %%
#calculate std of each portfolio
daily_std_whale = whale_data.std()
daily_std_whale
# Out:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64

# %%
daily_std_algo = algo_data.std()
daily_std_algo
# Out:
# Algo 1    0.007988
# Algo 2    0.008466
# dtype: float64

# %%
daily_std_sp500 = sp500_data.std()
daily_std_sp500
# Out:
# SP500 Close    0.008135
# dtype: float64

# %%
all_portfolios.std().sort_values()
# Out:
# PAULSON & CO.INC.              0.007026
# Algo 1                         0.007623
# SOROS FUND MANAGEMENT LLC      0.007896
# Algo 2                         0.008341
# SP500 Close                    0.008587
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# dtype: float64

# %%
'''
based on the std of each portfolio, the less risky investments compared to the SP500 are: Paulson & Co, Algo 1, Soros Fund Management LLC, and Algo 2, in that order. 
The reason being that they all have smaller std that the SP500 which makes them less volatile. The remaining portfolios are more risky than the SP500
'''
# Out:
# '\nbased on the std of each portfolio, the less risky investments compared to the SP500 are: Paulson & Co, Algo 1, Soros Fund Management LLC, and Algo 2, in that order. \nThe reason being that they all have smaller std that the SP500 which makes them less volatile. The remaining portfolios are more risky than the SP500\n'

# %%
#calculate the annualized std
annualized_std_whale = daily_std_whale * np.sqrt(252)
annualized_std_whale
# Out:
# SOROS FUND MANAGEMENT LLC      0.124487
# PAULSON & CO.INC.              0.110754
# TIGER GLOBAL MANAGEMENT LLC    0.171830
# BERKSHIRE HATHAWAY INC         0.203682
# dtype: float64

# %%
annualized_std_algo = daily_std_algo * np.sqrt(252)
annualized_std_algo
# Out:
# Algo 1    0.126801
# Algo 2    0.134401
# dtype: float64

# %%
annualized_std_sp500 = daily_std_sp500 * np.sqrt(252)
annualized_std_sp500
# Out:
# SP500 Close    0.129133
# dtype: float64

# %% [markdown]
# ### Rolling Statistics

# %%
algo_data.rolling(window = 21).std().plot(figsize = (15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
whale_data.rolling(window = (21)).std().plot(figsize = (15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sp500_data.rolling(window = 21).std().plot(figsize = (15,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#calculate the correlation
algo_data.corr()
# Out:
#           Algo 1    Algo 2
# Algo 1  1.000000  0.346568
# Algo 2  0.346568  1.000000

# %%
correlation_all_portfolios = all_portfolios.corr()
correlation_all_portfolios
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# SP500 Close                                   0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# Algo 2                                          0.507160
# SP500 Close                                    -0.001505
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754157  0.320901  0.826730
# PAULSON & CO.INC.                          0.545451  0.268631  0.678085
# TIGER GLOBAL MANAGEMENT LLC                0.424125  0.164114  0.507160
# BERKSHIRE HATHAWAY INC                     1.000000  0.291678  0.687756
# Algo 1                                     0.291678  1.000000  0.287852
# Algo 2                                     0.687756  0.287852  1.000000
# SP500 Close                               -0.013856 -0.033963 -0.002192
#
#                              SP500 Close
# SOROS FUND MANAGEMENT LLC       0.000574
# PAULSON & CO.INC.               0.013549
# TIGER GLOBAL MANAGEMENT LLC    -0.001505
# BERKSHIRE HATHAWAY INC         -0.013856
# Algo 1                         -0.033963
# Algo 2                         -0.002192
# SP500 Close                     1.000000

# %%
#create a heatmap for the correlation
sns.heatmap(correlation_all_portfolios, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta

# %%
#calculate the daily return of a single portfolio to calculate the covariance 
daily_returns_algo = algo_data.pct_change()
daily_returns_algo
# Out:
#               Algo 1     Algo 2
# Date
# 2014-06-05       NaN        NaN
# 2014-06-06 -0.542965  -0.376459
# 2014-06-09 -3.699287  -0.315757
# 2014-06-10 -1.879164  -1.129760
# 2014-06-11  0.080354   4.113963
# ...              ...        ...
# 2019-04-25 -0.376856 -19.155592
# 2019-04-26  3.368192  -1.725170
# 2019-04-29  0.746957  -0.461657
# 2019-04-30 -1.565269  -1.554776
# 2019-05-01 -1.031829   3.687689
#
# [1235 rows x 2 columns]

# %%
#calculate the covariance of the algo portfolio
covariance_algo = daily_returns_algo.cov()
covariance_algo
# Out:
#             Algo 1         Algo 2
# Algo 1  290.730581      -5.909837
# Algo 2   -5.909837  395323.806959

# %%
#calculate the variance 
variance_algo = daily_returns_algo.var()
variance_algo
# Out:
# Algo 1       290.730581
# Algo 2    395323.806959
# dtype: float64

# %%
beta_algo = covariance_algo / variance_algo
beta_algo
# Out:
#           Algo 1    Algo 2
# Algo 1  1.000000 -0.000015
# Algo 2 -0.020328  1.000000

# %%
all_portfolios.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SP500 Close
# Date
# 2015-03-03 -0.000949     0.004408
# 2015-03-04  0.002416    -0.001195
# 2015-03-05  0.004323     0.014378
# 2015-03-06 -0.011460    -0.003929
# 2015-03-09  0.001303     0.017254

# %% [markdown]
# ### Sharpe Ratio

# %% [markdown]
# ### Custom Portfolio

# %%
#find out what path you are in
Path.cwd()
# Out:
# WindowsPath('C:/Users/javie/OneDrive/Desktop/NorthWestern/Whale-off-the-Portfolio')

# %%
#read in the files
nke_df = pd.read_csv('C:/Users/javie/OneDrive/Desktop/NorthWestern/NKE.csv', index_col = 'Date')
mcd_df = pd.read_csv('C:/Users/javie/OneDrive/Desktop/NorthWestern/MCD.csv', index_col = 'Date')
sbux_df = pd.read_csv('C:/Users/javie/OneDrive/Desktop/NorthWestern/SBUX.csv', index_col = 'Date')
sbux_df
# Out:
#                  Open        High         Low       Close   Adj Close  \
# Date
# 4/15/2020   72.010002   73.180000   70.709999   72.550003   70.830666
# 4/16/2020   73.110001   73.760002   71.349998   73.510002   71.767906
# 4/17/2020   76.620003   77.389999   74.970001   77.099998   75.272835
# 4/20/2020   76.019997   76.980003   75.080002   75.320000   73.535019
# 4/21/2020   73.400002   73.959999   71.739998   72.720001   70.996628
# ...               ...         ...         ...         ...         ...
# 5/10/2021  114.570000  116.089996  114.209999  114.300003  113.847031
# 5/11/2021  113.320000  113.690002  112.169998  113.550003  113.100006
# 5/12/2021  111.870003  112.389999  109.559998  109.790001  109.790001
# 5/13/2021  110.160004  111.180000  109.160004  110.489998  110.489998
# 5/14/2021  111.010002  111.589996  110.250000  111.199997  111.199997
#
#              Volume
# Date
# 4/15/2020  10642500
# 4/16/2020  11946800
# 4/17/2020  14268400
# 4/20/2020   9684700
# 4/21/2020  10345800
# ...             ...
# 5/10/2021   5759500
# 5/11/2021   7775400
# 5/12/2021   7965300
# 5/13/2021   7999400
# 5/14/2021   6835300
#
# [274 rows x 6 columns]

# %%
#combine all the portfolios by the columns
combined_custom_portfolio = pd.concat([nke_df,mcd_df,sbux_df], axis = 'columns', join = 'inner')
combined_custom_portfolio.head()
# Out:
#                 Open       High        Low      Close  Adj Close   Volume  \
# Date
# 4/15/2020  84.870003  85.879997  83.709999  85.040001  84.299553  8053900
# 4/16/2020  85.430000  86.529999  84.550003  86.300003  85.548592  9373800
# 4/17/2020  89.000000  90.250000  88.360001  89.910004  89.127159  8111400
# 4/20/2020  88.430000  89.440002  87.519997  87.900002  87.134659  7244400
# 4/21/2020  85.989998  86.900002  85.089996  85.199997  84.458160  6597000
#
#                  Open        High         Low       Close   Adj Close  \
# Date
# 4/15/2020  178.740005  180.970001  177.270004  177.839996  173.529160
# 4/16/2020  177.000000  179.910004  172.270004  179.500000  175.148941
# 4/17/2020  182.320007  186.809998  180.229996  186.100006  181.588959
# 4/20/2020  184.449997  185.779999  181.550003  181.649994  177.246796
# 4/21/2020  177.369995  179.389999  176.100006  177.580002  173.275467
#
#             Volume       Open       High        Low      Close  Adj Close  \
# Date
# 4/15/2020  4961500  72.010002  73.180000  70.709999  72.550003  70.830666
# 4/16/2020  7120800  73.110001  73.760002  71.349998  73.510002  71.767906
# 4/17/2020  6467600  76.620003  77.389999  74.970001  77.099998  75.272835
# 4/20/2020  3856500  76.019997  76.980003  75.080002  75.320000  73.535019
# 4/21/2020  4758300  73.400002  73.959999  71.739998  72.720001  70.996628
#
#              Volume
# Date
# 4/15/2020  10642500
# 4/16/2020  11946800
# 4/17/2020  14268400
# 4/20/2020   9684700
# 4/21/2020  10345800

# %%
#drop all columns except for the adjusted close
combined_custom_portfolio = combined_custom_portfolio.drop(columns = ['Open','High','Low','Close'])
combined_custom_portfolio.head()
# Out:
#            Adj Close   Volume   Adj Close   Volume  Adj Close    Volume
# Date
# 4/15/2020  84.299553  8053900  173.529160  4961500  70.830666  10642500
# 4/16/2020  85.548592  9373800  175.148941  7120800  71.767906  11946800
# 4/17/2020  89.127159  8111400  181.588959  6467600  75.272835  14268400
# 4/20/2020  87.134659  7244400  177.246796  3856500  73.535019   9684700
# 4/21/2020  84.458160  6597000  173.275467  4758300  70.996628  10345800

# %%
#show all the columns
combined_custom_portfolio.head()
# Out:
#            Adj Close   Volume   Adj Close   Volume  Adj Close    Volume
# Date
# 4/15/2020  84.299553  8053900  173.529160  4961500  70.830666  10642500
# 4/16/2020  85.548592  9373800  175.148941  7120800  71.767906  11946800
# 4/17/2020  89.127159  8111400  181.588959  6467600  75.272835  14268400
# 4/20/2020  87.134659  7244400  177.246796  3856500  73.535019   9684700
# 4/21/2020  84.458160  6597000  173.275467  4758300  70.996628  10345800

# %%
#drop the volume column
combined_custom_portfolio = combined_custom_portfolio.drop(columns = ['Volume'])
combined_custom_portfolio.head()
# Out:
#            Adj Close   Adj Close  Adj Close
# Date
# 4/15/2020  84.299553  173.529160  70.830666
# 4/16/2020  85.548592  175.148941  71.767906
# 4/17/2020  89.127159  181.588959  75.272835
# 4/20/2020  87.134659  177.246796  73.535019
# 4/21/2020  84.458160  173.275467  70.996628

# %%
#display columns side by side
columns = ['NKE Adj Close', 'MCD Adj Close', 'SBUX Adj Close']
combined_custom_portfolio.columns = columns
combined_custom_portfolio.head()
# Out:
#            NKE Adj Close  MCD Adj Close  SBUX Adj Close
# Date
# 4/15/2020      84.299553     173.529160       70.830666
# 4/16/2020      85.548592     175.148941       71.767906
# 4/17/2020      89.127159     181.588959       75.272835
# 4/20/2020      87.134659     177.246796       73.535019
# 4/21/2020      84.458160     173.275467       70.996628

# %%
#count the nulls
combined_custom_portfolio.isnull().sum()
# Out:
# NKE Adj Close     0
# MCD Adj Close     0
# SBUX Adj Close    0
# dtype: int64

# %%
#calculate the daily returns for the portfolios
daily_returns_custom  = combined_custom_portfolio.pct_change()
daily_returns_custom.head()
# Out:
#            NKE Adj Close  MCD Adj Close  SBUX Adj Close
# Date
# 4/15/2020            NaN            NaN             NaN
# 4/16/2020       0.014817       0.009334        0.013232
# 4/17/2020       0.041831       0.036769        0.048837
# 4/20/2020      -0.022356      -0.023912       -0.023087
# 4/21/2020      -0.030717      -0.022406       -0.034519

# %%
#drop the nulls and display the data
daily_returns_custom = daily_returns_custom.dropna()
daily_returns_custom.head()
# Out:
#            NKE Adj Close  MCD Adj Close  SBUX Adj Close
# Date
# 4/16/2020       0.014817       0.009334        0.013232
# 4/17/2020       0.041831       0.036769        0.048837
# 4/20/2020      -0.022356      -0.023912       -0.023087
# 4/21/2020      -0.030717      -0.022406       -0.034519
# 4/22/2020       0.041901       0.050118        0.065044

# %%
#set weights
weights = [1/3, 1/3, 1/3]
